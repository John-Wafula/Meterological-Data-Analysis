# %% [markdown]
# # Bureau of Meteorology (BOM) Data Analysis

# %%
import pandas as pd  #pandas
data = pd.read_csv("C:/Users/Admin/Documents/D1.csv")
data.head()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (27) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Unnamed: 0       Date  Day  Month     Location  MinTemp  MaxTemp  Rainfall  \
# 0           1  1/11/2008    1     11  Archerfield     13.8     23.0       0.7
# 1           2  2/11/2008    2     11  Archerfield      7.4     25.1       0.0
# 2           3  3/11/2008    3     11  Archerfield     12.9     25.7       0.0
# 3           4  4/11/2008    4     11  Archerfield      9.2     28.0       0.0
# 4           5  5/11/2008    5     11  Archerfield     17.5     32.3       1.0
#
#    Evaporation  Sunshine  ... Pressure9am  Pressure3pm Cloud9am Cloud3pm  \
# 0          NaN       NaN  ...      1007.7       1007.1      8.0      NaN
# 1          NaN       NaN  ...      1010.6       1007.8      NaN      NaN
# ...

# %%
data.head()
# Out:
#    Unnamed: 0       Date  Day  Month     Location  MinTemp  MaxTemp  Rainfall  \
# 0           1  1/11/2008    1     11  Archerfield     13.8     23.0       0.7
# 1           2  2/11/2008    2     11  Archerfield      7.4     25.1       0.0
# 2           3  3/11/2008    3     11  Archerfield     12.9     25.7       0.0
# 3           4  4/11/2008    4     11  Archerfield      9.2     28.0       0.0
# 4           5  5/11/2008    5     11  Archerfield     17.5     32.3       1.0
#
#    Evaporation  Sunshine  ... Pressure9am  Pressure3pm Cloud9am Cloud3pm  \
# 0          NaN       NaN  ...      1007.7       1007.1      8.0      NaN
# 1          NaN       NaN  ...      1010.6       1007.8      NaN      NaN
# 2          NaN       NaN  ...      1007.6       1008.7      NaN      2.0
# 3          NaN       NaN  ...      1017.6       1012.8      NaN      NaN
# 4          NaN       NaN  ...      1010.8       1006.0      7.0      8.0
#
# ...

# %%
data.describe()
# Out:
#          Unnamed: 0            Day          Month        MinTemp  \
# count  145490.00000  145490.000000  145490.000000  144005.000000
# mean    72745.50000      15.712214       6.400564      12.194325
# std     41999.48967       8.794761       3.427545       6.398058
# min         1.00000       1.000000       1.000000      -8.500000
# 25%     36373.25000       8.000000       3.000000       7.600000
# 50%     72745.50000      16.000000       6.000000      12.000000
# 75%    109117.75000      23.000000       9.000000      16.900000
# max    145490.00000      31.000000      12.000000      33.900000
#
#              MaxTemp       Rainfall   Evaporation      Sunshine  \
# count  144229.000000  142228.000000  82670.000000  75625.000000
# mean       23.222217       2.360812      5.468232      7.611178
# std         7.118832       8.477432      4.193704      3.785483
# min        -4.800000       0.000000      0.000000      0.000000
# ...

# %%
data.head()
# Out:
#    Unnamed: 0       Date  Day  Month     Location  MinTemp  MaxTemp  Rainfall  \
# 0           1  1/11/2008    1     11  Archerfield     13.8     23.0       0.7
# 1           2  2/11/2008    2     11  Archerfield      7.4     25.1       0.0
# 2           3  3/11/2008    3     11  Archerfield     12.9     25.7       0.0
# 3           4  4/11/2008    4     11  Archerfield      9.2     28.0       0.0
# 4           5  5/11/2008    5     11  Archerfield     17.5     32.3       1.0
#
#    Evaporation  Sunshine  ... Pressure9am  Pressure3pm Cloud9am Cloud3pm  \
# 0          NaN       NaN  ...      1007.7       1007.1      8.0      NaN
# 1          NaN       NaN  ...      1010.6       1007.8      NaN      NaN
# 2          NaN       NaN  ...      1007.6       1008.7      NaN      2.0
# 3          NaN       NaN  ...      1017.6       1012.8      NaN      NaN
# 4          NaN       NaN  ...      1010.8       1006.0      7.0      8.0
#
# ...

# %%
data.dtypes
# Out:
# Unnamed: 0         int64
# Date              object
# Day                int64
# Month              int64
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainLastWeek      object
# RainToday         object
# RainTomorrow      object
# ENSO              object
# dtype: object

# %% [markdown]
# 1. Examine the data types assigned by the `Pandas’ library for each variable in
# Table 1. Check/assess them with the dataset description provided in Table 1.
# If there seems to be a mismatch in the data type assigned by the library and
# the data type as per the description for a variable, correct that data type.
# Details about the data types that required correction should be included.
# Finally, attach a screenshot showing the corrected data types of all variables.

# %%
# convert the 'Date' column to datetime format
data['Date']= pd.to_datetime(data['Date'])

# Check the format of 'Date' column
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145490 entries, 0 to 145489
# Data columns (total 28 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Unnamed: 0     145490 non-null  int64
#  1   Date           145490 non-null  datetime64[ns]
#  2   Day            145490 non-null  datetime64[ns]
#  3   Month          145490 non-null  datetime64[ns]
#  4   Location       145490 non-null  object
#  5   MinTemp        144005 non-null  float64
#  6   MaxTemp        144229 non-null  float64
#  7   Rainfall       142228 non-null  float64
#  8   Evaporation    82670 non-null   float64
#  9   Sunshine       75625 non-null   float64
#  10  WindGustDir    135163 non-null  object
#  11  WindGustSpeed  135226 non-null  float64
#  12  WindDir9am     134922 non-null  object
#  13  WindDir3pm     141262 non-null  object
#  14  WindSpeed9am   143722 non-null  float64
#  15  WindSpeed3pm   142428 non-null  float64
# ...

# %%
# convert the 'Day' column to datetime format
data['Day']= pd.to_datetime(data['Day'])

# Check the format of 'Date' column
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145490 entries, 0 to 145489
# Data columns (total 28 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Unnamed: 0     145490 non-null  int64
#  1   Date           145490 non-null  datetime64[ns]
#  2   Day            145490 non-null  datetime64[ns]
#  3   Month          145490 non-null  datetime64[ns]
#  4   Location       145490 non-null  object
#  5   MinTemp        144005 non-null  float64
#  6   MaxTemp        144229 non-null  float64
#  7   Rainfall       142228 non-null  float64
#  8   Evaporation    82670 non-null   float64
#  9   Sunshine       75625 non-null   float64
#  10  WindGustDir    135163 non-null  object
#  11  WindGustSpeed  135226 non-null  float64
#  12  WindDir9am     134922 non-null  object
#  13  WindDir3pm     141262 non-null  object
#  14  WindSpeed9am   143722 non-null  float64
#  15  WindSpeed3pm   142428 non-null  float64
# ...

# %%
# convert the 'month' column to datetime format
data['Month']= pd.to_datetime(data['Month'])

# Check the format of 'Date' column
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145490 entries, 0 to 145489
# Data columns (total 28 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Unnamed: 0     145490 non-null  int64
#  1   Date           145490 non-null  datetime64[ns]
#  2   Day            145490 non-null  datetime64[ns]
#  3   Month          145490 non-null  datetime64[ns]
#  4   Location       145490 non-null  object
#  5   MinTemp        144005 non-null  float64
#  6   MaxTemp        144229 non-null  float64
#  7   Rainfall       142228 non-null  float64
#  8   Evaporation    82670 non-null   float64
#  9   Sunshine       75625 non-null   float64
#  10  WindGustDir    135163 non-null  object
#  11  WindGustSpeed  135226 non-null  float64
#  12  WindDir9am     134922 non-null  object
#  13  WindDir3pm     141262 non-null  object
#  14  WindSpeed9am   143722 non-null  float64
#  15  WindSpeed3pm   142428 non-null  float64
# ...

# %%
data['RainToday'] = data['RainToday'].astype('bool')

# %%
data['RainLastWeek'] = data['RainLastWeek'].astype('bool')

# %%
data['RainTomorrow'] = data['RainTomorrow'].astype('bool')

# %%
data['ENSO'] = data['ENSO'].astype('bool')

# %%
data.drop('RainToday',
  axis='columns', inplace=True)

# %%
data.head()
# Out:
#    Unnamed: 0       Date                           Day  \
# 0           1 2008-01-11 1970-01-01 00:00:00.000000001
# 1           2 2008-02-11 1970-01-01 00:00:00.000000002
# 2           3 2008-03-11 1970-01-01 00:00:00.000000003
# 3           4 2008-04-11 1970-01-01 00:00:00.000000004
# 4           5 2008-05-11 1970-01-01 00:00:00.000000005
#
#                           Month     Location  MinTemp  MaxTemp  Rainfall  \
# 0 1970-01-01 00:00:00.000000011  Archerfield     13.8     23.0       0.7
# 1 1970-01-01 00:00:00.000000011  Archerfield      7.4     25.1       0.0
# 2 1970-01-01 00:00:00.000000011  Archerfield     12.9     25.7       0.0
# 3 1970-01-01 00:00:00.000000011  Archerfield      9.2     28.0       0.0
# 4 1970-01-01 00:00:00.000000011  Archerfield     17.5     32.3       1.0
#
#    Evaporation  Sunshine  ... Pressure9am  Pressure3pm Cloud9am Cloud3pm  \
# 0          NaN       NaN  ...      1007.7       1007.1      8.0      NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145490 entries, 0 to 145489
# Data columns (total 28 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Unnamed: 0     145490 non-null  int64
#  1   Date           145490 non-null  datetime64[ns]
#  2   Day            145490 non-null  datetime64[ns]
#  3   Month          145490 non-null  datetime64[ns]
#  4   Location       145490 non-null  object
#  5   MinTemp        144005 non-null  float64
#  6   MaxTemp        144229 non-null  float64
#  7   Rainfall       142228 non-null  float64
#  8   Evaporation    82670 non-null   float64
#  9   Sunshine       75625 non-null   float64
#  10  WindGustDir    135163 non-null  object
#  11  WindGustSpeed  135226 non-null  float64
#  12  WindDir9am     134922 non-null  object
#  13  WindDir3pm     141262 non-null  object
#  14  WindSpeed9am   143722 non-null  float64
#  15  WindSpeed3pm   142428 non-null  float64
# ...

# %%
data.describe()
# Out:
#          Unnamed: 0        MinTemp        MaxTemp       Rainfall  \
# count  145490.00000  144005.000000  144229.000000  142228.000000
# mean    72745.50000      12.194325      23.222217       2.360812
# std     41999.48967       6.398058       7.118832       8.477432
# min         1.00000      -8.500000      -4.800000       0.000000
# 25%     36373.25000       7.600000      17.900000       0.000000
# 50%     72745.50000      12.000000      22.600000       0.000000
# 75%    109117.75000      16.900000      28.200000       0.800000
# max    145490.00000      33.900000      48.100000     371.000000
#
#         Evaporation      Sunshine  WindGustSpeed   WindSpeed9am  \
# count  82670.000000  75625.000000  135226.000000  143722.000000
# mean       5.468232      7.611178      40.035829      14.043257
# std        4.193704      3.785483      13.606994       8.915057
# min        0.000000      0.000000       6.000000       0.000000
# ...

# %%
data.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Unnamed: 0'}>,
#         <AxesSubplot:title={'center':'Date'}>,
#         <AxesSubplot:title={'center':'Day'}>,
#         <AxesSubplot:title={'center':'Month'}>],
#        [<AxesSubplot:title={'center':'MinTemp'}>,
#         <AxesSubplot:title={'center':'MaxTemp'}>,
#         <AxesSubplot:title={'center':'Rainfall'}>,
#         <AxesSubplot:title={'center':'Evaporation'}>],
#        [<AxesSubplot:title={'center':'Sunshine'}>,
#         <AxesSubplot:title={'center':'WindGustSpeed'}>,
#         <AxesSubplot:title={'center':'WindSpeed9am'}>,
#         <AxesSubplot:title={'center':'WindSpeed3pm'}>],
#        [<AxesSubplot:title={'center':'Humidity9am'}>,
#         <AxesSubplot:title={'center':'Humidity3pm'}>,
#         <AxesSubplot:title={'center':'Pressure9am'}>,
#         <AxesSubplot:title={'center':'Pressure3pm'}>],
#        [<AxesSubplot:title={'center':'Cloud9am'}>,
#         <AxesSubplot:title={'center':'Cloud3pm'}>,
# ...

# %%
data['MaxTemp'].hist()
# Out:
# <AxesSubplot:>

# %%
data['Sunshine'].hist()
# Out:
# <AxesSubplot:>

# %%
data['Rainfall'].hist()
# Out:
# <AxesSubplot:>

# %%
data['WindGustSpeed'].hist()
# Out:
# <AxesSubplot:>

# %%
data['Evaporation'].hist()
# Out:
# <AxesSubplot:>

# %%
data['Humidity9am'].hist()
# Out:
# <AxesSubplot:>

# %%
data['WindSpeed9am'].hist()
# Out:
# <AxesSubplot:>

# %%
data['WindSpeed3pm'].hist()
# Out:
# <AxesSubplot:>

# %%
# Count number of missing values per column
missingCount = data.isnull().sum()
missingCount
# Out:
# Unnamed: 0            0
# Date                  0
# Day                   0
# Month                 0
# Location              0
# MinTemp            1485
# MaxTemp            1261
# Rainfall           3262
# Evaporation       62820
# Sunshine          69865
# WindGustDir       10327
# WindGustSpeed     10264
# WindDir9am        10568
# WindDir3pm         4228
# WindSpeed9am       1768
# WindSpeed3pm       3062
# Humidity9am        2654
# Humidity3pm        4507
# Pressure9am       15065
# Pressure3pm       15028
# Cloud9am          55908
# Cloud3pm          59376
# Temp9am            1767
# Temp3pm            3609
# RainLastWeek       3262
# RainToday          3262
# RainTomorrow       3268
# ENSO             131826
# dtype: int64

# %%
data.plot.bar(x = 'MaxTemp', y = 'MinTemp', rot = 40)
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# Determine if there is any relationship between the variables
# Humidity3pm and Pressure3pm? How would you handle these two
# variables in the data modelling if a relationship exists?

# %%
from scipy.stats import pearsonr
corr, _ = pearsonr(data["Humidity3pm"],data["Pressure3pm"])
print('Pearsons correlation: %.3f' % corr)

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
f,ax = plt.subplots(figsize=(18, 18))
sns.heatmap(data.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()

# %%
sns.countplot(y=data['Sunshine'])
# Out:
# <AxesSubplot:xlabel='count', ylabel='Sunshine'>

# %%
data['Sunshine'].value_counts(dropna=False)
# Out:
# NaN     69865
# 0.0      2359
# 10.7     1101
# 11.0     1094
# 10.8     1069
#         ...
# 14.0       15
# 14.1        6
# 14.3        4
# 14.2        2
# 14.5        1
# Name: Sunshine, Length: 146, dtype: int64

# %%
data2 = data[['Location', 'Rainfall']]

# %%
data2.head
# Out:
# <bound method NDFrame.head of            Location  Rainfall
# 0       Archerfield       0.7
# 1       Archerfield       0.0
# 2       Archerfield       0.0
# 3       Archerfield       0.0
# 4       Archerfield       1.0
# ...             ...       ...
# 145485        Uluru       0.0
# 145486        Uluru       0.0
# 145487        Uluru       0.0
# 145488        Uluru       0.0
# 145489        Uluru       0.0
#
# [145490 rows x 2 columns]>

# %%
max(data2['Rainfall'])
# Out:
# 371.0

# %%
dete = data2.groupby(["Location", "Rainfall"]).size().reset_index(name="Count").max()

# %%
dete
# Out:
# Location    Woomera
# Rainfall      371.0
# Count          2665
# dtype: object

# %% [markdown]
# List the top-5 locations based on the total amount of rainfall
# recorded in 2017

# %%
df1 = data.groupby(['Location'])['Rainfall'].max().reset_index()
df1
# Out:
#             Location  Rainfall
# 0           Adelaide      75.2
# 1             Albany      49.4
# 2       AliceSprings      62.0
# 3        Archerfield     104.2
# 4      BadgerysCreek     116.0
# 5           Ballarat      95.0
# 6            Bendigo      66.4
# 7           Brisbane     182.6
# 8             Cairns     278.4
# 9           Canberra      87.0
# 10             Cobar      68.0
# 11      CoffsHarbour     371.0
# 12          Dartmoor      73.6
# 13            Darwin     367.6
# 14         GoldCoast     183.4
# 15            Hobart      71.6
# 16         Katherine     167.0
# 17        Launceston      88.0
# 18         Melbourne      82.2
# 19  MelbourneAirport      75.8
# 20           Mildura     155.0
# 21             Moree     113.0
# 22      MountGambier      84.6
# 23       MountGinini     107.6
# 24         Newcastle     240.0
# 25              Nhil      65.6
# 26         NorahHead     126.4
# 27     NorfolkIsland     156.8
# 28         Nuriootpa      76.6
# ...

# %%
df1.sort_values("Rainfall", ascending=False)
# Out:
#             Location  Rainfall
# 11      CoffsHarbour     371.0
# 13            Darwin     367.6
# 8             Cairns     278.4
# 24         Newcastle     240.0
# 39        Townsville     236.8
# 45       Williamtown     225.0
# 47        Wollongong     192.0
# 14         GoldCoast     183.4
# 7           Brisbane     182.6
# 16         Katherine     167.0
# 27     NorfolkIsland     156.8
# 20           Mildura     155.0
# 26         NorahHead     126.4
# 37            Sydney     119.4
# 4      BadgerysCreek     116.0
# 30           Penrith     115.4
# 31             Perth     114.4
# 34          Richmond     113.4
# 21             Moree     113.0
# 42        WaggaWagga     110.8
# 23       MountGinini     107.6
# 38     SydneyAirport     106.8
# 3        Archerfield     104.2
# 46       Witchcliffe      99.4
# 5           Ballarat      95.0
# 43           Walpole      93.2
# 40       Tuggeranong      93.0
# 17        Launceston      88.0
# 44          Watsonia      87.4
# ...

# %%
data['WindGustDir'].value_counts(dropna=False)
# Out:
# NaN    10327
# W       9923
# SE      9418
# N       9315
# SSE     9218
# E       9181
# S       9169
# WSW     9072
# SW      8968
# SSW     8736
# WNW     8259
# NW      8122
# ENE     8105
# ESE     7372
# NE      7135
# NNW     6621
# NNE     6549
# Name: WindGustDir, dtype: int64

# %% [markdown]
# . Give a summary of the wind directions such as the frequency of a
# particular wind direction when it was a rainy day.

# %%
df2 = data.groupby(['WindGustDir'])['Rainfall'].max().reset_index()
df2
# Out:
#    WindGustDir  Rainfall
# 0            E     247.2
# 1          ENE     268.6
# 2          ESE     236.8
# 3            N     161.6
# 4           NE     178.2
# 5          NNE     208.5
# 6          NNW     129.4
# 7           NW     278.4
# 8            S     225.0
# 9           SE     206.2
# 10         SSE     156.0
# 11         SSW     182.6
# 12          SW     157.8
# 13           W     167.0
# 14         WNW     210.6
# 15         WSW     367.6

# %%
df2.sort_values("Rainfall", ascending=False)
# Out:
#    WindGustDir  Rainfall
# 15         WSW     367.6
# 7           NW     278.4
# 1          ENE     268.6
# 0            E     247.2
# 2          ESE     236.8
# 8            S     225.0
# 14         WNW     210.6
# 5          NNE     208.5
# 9           SE     206.2
# 11         SSW     182.6
# 4           NE     178.2
# 13           W     167.0
# 3            N     161.6
# 12          SW     157.8
# 10         SSE     156.0
# 6          NNW     129.4

# %% [markdown]
# What was the average maximum temperature recorded in 2016 in
# Uluru when the sudden burst in wind speed was in the Southerly
# direction?

# %%
df3 = data.groupby(["MaxTemp", "WindGustDir","Location"]).size().reset_index(name="Count")
df3
# Out:
#        MaxTemp WindGustDir     Location  Count
# 0         -4.8         WSW  MountGinini      1
# 1         -4.1           W  MountGinini      1
# 2         -3.8         WSW  MountGinini      1
# 3         -3.7           W  MountGinini      1
# 4         -3.2         WSW  MountGinini      1
# ...        ...         ...          ...    ...
# 74416     46.9           W      Penrith      1
# 74417     47.0          SW     Richmond      1
# 74418     47.3         SSW        Moree      1
# 74419     47.3         WSW        Moree      1
# 74420     48.1         WSW      Woomera      1
#
# [74421 rows x 4 columns]

# %%
df3.sort_values("MaxTemp", ascending=False)
# Out:
#        MaxTemp WindGustDir     Location  Count
# 74420     48.1         WSW      Woomera      1
# 74419     47.3         WSW        Moree      1
# 74418     47.3         SSW        Moree      1
# 74417     47.0          SW     Richmond      1
# 74416     46.9           W      Penrith      1
# ...        ...         ...          ...    ...
# 4         -3.2         WSW  MountGinini      1
# 3         -3.7           W  MountGinini      1
# 2         -3.8         WSW  MountGinini      1
# 1         -4.1           W  MountGinini      1
# 0         -4.8         WSW  MountGinini      1
#
# [74421 rows x 4 columns]

# %%
df3['MaxTemp'].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0       -4.8
# 1       -4.1
# 2       -3.8
# 3       -3.7
# 4       -3.2
#         ...
# 6330    46.9
# 6331    47.0
# 6332    47.3
# 6333    47.3
# 6334    48.1
# Name: MaxTemp, Length: 6335, dtype: float64>

# %%
import statistics
statistics.mean(df3['MaxTemp'])
# Out:
# 23.710797158642464

# %% [markdown]
# 4) Answer the followings:
# a. Give the details (location and month) of the longest day (the day
# which had the most sunshine) recorded in this dataset

# %%
df4 = data.groupby(["Day", "Date","Sunshine","Location","Month"]).size().reset_index(name="Count")
df4
# Out:
#        Day       Date  Sunshine      Location                         Month  \
# 0        1 2007-01-11       6.3      Canberra 1970-01-01 00:00:00.000000011
# 1        1 2007-01-12       0.2      Canberra 1970-01-01 00:00:00.000000012
# 2        1 2008-01-01      12.8      Canberra 1970-01-01 00:00:00.000000001
# 3        1 2008-01-02       0.0        Sydney 1970-01-01 00:00:00.000000002
# 4        1 2008-01-02       6.2      Canberra 1970-01-01 00:00:00.000000002
# ...    ...        ...       ...           ...                           ...
# 75620   31 2017-05-31       8.0  PerthAirport 1970-01-01 00:00:00.000000005
# 75621   31 2017-05-31       8.6     Nuriootpa 1970-01-01 00:00:00.000000005
# 75622   31 2017-05-31       9.0       Mildura 1970-01-01 00:00:00.000000005
# 75623   31 2017-05-31       9.6        Darwin 1970-01-01 00:00:00.000000005
# 75624   31 2017-05-31      10.0      Brisbane 1970-01-01 00:00:00.000000005
#
#        Count
# 0          1
# 1          1
# ...

# %%
df4.sort_values("Sunshine", ascending=False)
# Out:
#        Day       Date  Sunshine          Location  \
# 69328   28 2015-12-28      14.5           Mildura
# 15338    7 2010-07-01      14.3          Dartmoor
# 70567   29 2011-12-29      14.3         Nuriootpa
# 15340    7 2010-07-01      14.3          Portland
# 15339    7 2010-07-01      14.3      MountGambier
# ...    ...        ...       ...               ...
# 21393    9 2013-09-07       0.0            Albany
# 21394    9 2013-09-07       0.0      AliceSprings
# 67051   27 2016-12-27       0.0         Melbourne
# 67052   27 2016-12-27       0.0  MelbourneAirport
# 63714   26 2013-08-26       0.0            Albany
#
#                               Month  Count
# 69328 1970-01-01 00:00:00.000000012      1
# 15338 1970-01-01 00:00:00.000000001      1
# 70567 1970-01-01 00:00:00.000000012      1
# 15340 1970-01-01 00:00:00.000000001      1
# 15339 1970-01-01 00:00:00.000000001      1
# ...                             ...    ...
# 21393 1970-01-01 00:00:00.000000007      1
# ...
